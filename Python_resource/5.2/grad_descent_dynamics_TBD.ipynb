# %% [markdown]
# # Section 5.2: Gradient descent dynamics in learning linear neural networks
#
# This page contains simulations in Section 5.2.
#
# ## Contents
#
#     - Training and test error rates as a function of the training time
#     - Test performance with positive regularization
#     - FUNCTIONS
#
#
# ## Training and test error rates as a function of the training time

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.integrate
import scipy.special
pi = np.pi

# %%
p = 256
n = 512
n_test = n
c = p/n

mu = np.concatenate([-np.ones(p//2),np.ones(p//2)])/np.sqrt(p)
norm_mu2 = np.linalg.norm(mu)**2
gamma = 0  # regularization penalty

t_max = 1000
alpha = 1e-2

sigma2_init = .1
w_init = np.sqrt(sigma2_init)*np.random.randn(p)/np.sqrt(p)


cs = [1/2,1/2]
lambda_s = c + 1 + norm_mu2 + c/norm_mu2

# Theory
tolerance = 1e-12

f  = lambda x,t : np.exp(-alpha*x*t)
omega = lambda x : np.sqrt(4*c*x - (1-c-x)**2)/(lambda_s-x)/2/pi
nu = lambda x : np.sqrt(4*c*x - (1-c-x)**2)/(2*pi*c*x)

E_test_func = lambda x,t : (1 - f(x+gamma,t))/(gamma+x)*omega(x)
E_test = lambda t : scipy.integrate.quadrature( lambda x : E_test_func(x,t), (1-np.sqrt(c))**2+tolerance, (1+np.sqrt(c))**2-tolerance,rtol=tolerance)[0] + np.max(norm_mu2**2-c,0)/norm_mu2*(1 - f(lambda_s+gamma,t))/(lambda_s+gamma)
V_test_func1 = lambda x,t : (1 - f(x+gamma,t))**2/((x+gamma)**2)*omega(x)
V_test_func2 = lambda x,t : (f(x+gamma,t))**2*nu(x)
V_test = lambda t : (norm_mu2+c)/norm_mu2*( scipy.integrate.quadrature( lambda x : V_test_func1(x,t), (1-np.sqrt(c))**2+tolerance, (1+np.sqrt(c))**2-tolerance,rtol=tolerance)[0] + np.max(norm_mu2**2-c,0)/norm_mu2*(1 - f(lambda_s+gamma,t))**2/((lambda_s+gamma)**2)) + sigma2_init*(scipy.integrate.quadrature( lambda x : V_test_func2(x,t), (1-np.sqrt(c))**2+tolerance, (1+np.sqrt(c))**2-tolerance,rtol=tolerance)[0] + np.max(1-1/c,0)*f(gamma,t)**2 )

E_train = lambda t : (norm_mu2+c)/norm_mu2*E_test(t)
V_train_func1 = lambda x,t : x*(1 - f(x+gamma,t))**2/((gamma+x)**2)*omega(x)
V_train_func2 = lambda x,t : x*(f(x+gamma,t))**2*nu(x)
V_train = lambda t : (norm_mu2+c)/norm_mu2*( scipy.integrate.quadrature( lambda x : V_train_func1(x,t), (1-np.sqrt(c))**2+tolerance, (1+np.sqrt(c))**2-tolerance,rtol=tolerance)[0] + np.max(norm_mu2**2-c,0)/norm_mu2*lambda_s*(1 - f(lambda_s+gamma,t))**2/((lambda_s+gamma)**2)) + sigma2_init*scipy.integrate.quadrature( lambda x : V_train_func2(x,t), (1-np.sqrt(c))**2+tolerance, (1+np.sqrt(c))**2-tolerance,rtol=tolerance)[0] - E_train(t)**2  #+ max(1-1/c,0)*0*f(gamma,t)**2

qfunc = lambda x : 0.5 - 0.5*scipy.special.erf(x/np.sqrt(2))

store_theory = np.zeros((t_max,2))
for t in range(t_max):
    store_theory[t,0] = qfunc(E_train(t)/np.sqrt(np.maximum(V_train(t),1e-20))) # train theory
    store_theory[t,1] = qfunc(E_test(t)/np.sqrt(np.maximum(V_test(t),1e-20))) # test theory


# Empirical
nb_data_loop = 1
store_perf = np.zeros((t_max,nb_data_loop,2))

for data_loop in range(nb_data_loop):

    y = np.concatenate([-np.ones(int(n*cs[0])),np.ones(int(n*cs[1]))])
    X = np.outer(mu,y) + np.random.randn(p,n)

    y_test = np.concatenate([-np.ones(int(n_test*cs[0])),np.ones(int(n_test*cs[1]))])
    X_test = np.outer(mu,y_test) + np.random.randn(p,n_test)

    w = w_init
    
    for t in range(t_max):
        store_perf[t,data_loop,0] = 1 - np.sum( np.sign(X.T@w)==y )/n # training error rate
        store_perf[t,data_loop,1] = 1 - np.sum( np.sign(X_test.T@w)==y_test )/n_test # test error rate
        w = gd(w, X, y, gamma, alpha, 1)

time=range(0,t_max,5)
plt.plot(time,np.mean(store_perf[time,:,0],1),'bx',label='Empirical training error')
plt.plot(time,np.mean(store_perf[time,:,1],1),'bo',label='Empirical test error')
plt.plot(time,store_theory[time,0],'r-',label='Asymptotic training error')
plt.plot(time,store_theory[time,1],'r--',label='Asymptotic test error')
_ = plt.legend()
# Out:
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.519295e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.538407e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.445818e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.533442e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.495609e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.376388e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.528621e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.212235e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.310774e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.523934e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.908869e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.248760e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.519375e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 3.586084e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.190144e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.514937e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 4.244439e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.134732e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.510613e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 4.884475e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.082343e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.506396e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 5.506718e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.032806e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.502281e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 6.111678e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.985961e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.498263e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 6.699852e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.641891e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.941654e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.494336e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 7.271722e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.932524e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.899742e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.490495e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 7.827756e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.237478e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.860089e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.486735e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 8.368407e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.555060e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.822569e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.483053e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 8.894119e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.883699e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.787059e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.479444e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 9.405319e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 3.221938e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.753447e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.475904e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 9.902424e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 3.568426e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.721625e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.472429e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.038584e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 3.921911e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.691492e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.469016e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.085596e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 4.281237e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.662952e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.535254e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.465662e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.131316e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 4.645332e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.635916e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.667708e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.462363e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.175781e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 5.013209e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.610298e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.801859e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.459117e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.219028e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 5.383956e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.586019e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.937392e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.455921e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.261092e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 5.756732e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.563002e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.074019e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.452772e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.302006e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 6.130766e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.541176e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.211475e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.449668e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.341803e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 6.505347e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.520475e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.349513e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.446607e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.380516e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 6.879824e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.500834e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.487910e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.443586e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.418175e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 7.253599e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.482193e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.626461e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.440603e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.454812e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 7.626128e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.464497e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.764977e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.437656e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.490454e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 7.996913e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.447691e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.903286e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.434744e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.525131e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 8.365500e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.431726e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 3.041232e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.431865e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.558870e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 8.731478e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.416555e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 3.178673e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.429017e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.591698e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 9.094475e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.402131e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 3.315480e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.426198e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.623642e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 9.454153e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.388414e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 3.451537e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.423408e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.654727e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 9.810210e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.375363e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 3.586738e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.420644e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.684977e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.016237e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.362941e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 3.720989e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.417906e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.714416e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.051040e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.351113e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 3.854207e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.415192e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.743067e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.085408e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.339844e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 3.986316e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.412501e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.770954e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.119321e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.329104e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 4.117250e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.409832e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.798098e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.152764e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.318862e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 4.246951e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.407184e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.824520e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.185721e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.309091e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 4.375368e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.404557e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.850242e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.218180e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.299764e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 4.502457e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.401948e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.875282e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.250131e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.290857e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 4.628181e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.399357e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.899661e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.281565e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.282345e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 4.752508e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.396784e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.923398e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.312473e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.274206e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 4.875412e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.394228e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.946511e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.342851e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.266420e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 4.996872e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.391687e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.969017e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.372694e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.258966e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 5.116871e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.389162e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.990935e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.401998e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.251826e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 5.235398e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.386651e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.012281e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.430762e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.244983e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 5.352444e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.384154e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.033072e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.458985e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.238419e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 5.468005e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.381671e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.053323e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.486666e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.232120e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 5.582079e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.379200e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.073050e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.513806e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.226070e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 5.694669e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.376742e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.092268e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.540407e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.220255e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 5.805778e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.374296e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.110991e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.566471e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.214662e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 5.915416e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.371861e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.129234e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.592002e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.209280e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 6.023590e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.369437e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.147010e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.617003e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.204095e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 6.130313e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.367024e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.164334e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.641478e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.199097e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 6.235598e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.364621e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.181216e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.665432e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.194276e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 6.339460e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.362227e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.197672e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.688871e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.189622e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 6.441917e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.359843e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.213711e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.711799e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.185126e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 6.542987e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.357469e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.229348e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.734223e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.180778e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 6.642689e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.355103e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.244592e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.756149e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.176571e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 6.741044e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.352745e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.259456e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.777584e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.172496e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 6.838074e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.350396e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.273949e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.798534e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.168547e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 6.933800e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.348055e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.288084e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.819008e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.164717e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 7.028247e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.345722e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.301869e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.839011e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.160998e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 7.121439e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.343396e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.315315e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.858551e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.157386e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 7.213399e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.341078e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.328432e-07
#   warnings.warn(
# ...
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 8.635557e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.776872e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.025180e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 3.003104e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.633225e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 8.621014e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.784259e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.023454e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 3.004995e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.634052e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 8.606496e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.791667e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.021731e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 3.006881e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.634874e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 8.592003e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.799096e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.020011e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 3.008762e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.635693e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 8.577534e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.806547e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.018294e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 3.010640e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.636508e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 8.563089e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.814019e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.016580e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 3.012513e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.637320e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 8.548669e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.821512e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.014869e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 3.014381e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.638128e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 8.534273e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.829027e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.013161e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 3.016246e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.638933e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 8.519901e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.836562e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.011456e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 3.018107e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.639734e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 8.505554e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.844119e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.009753e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 3.019964e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.640533e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 8.491231e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.851697e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.008053e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 3.021817e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.641329e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 8.476932e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.859297e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.006356e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 3.023666e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.642122e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 8.462657e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.866917e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.004663e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 3.025511e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.642913e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 8.448406e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.874558e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.002971e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 3.027353e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.643701e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 8.434179e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.882221e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.001283e-06
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 3.029191e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.644487e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 8.419977e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.889904e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 9.995977e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 3.031026e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.645271e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 8.405798e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.897609e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 9.979152e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 3.032857e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.646053e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 8.391643e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.905335e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 9.962354e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 3.034685e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.646833e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 8.377512e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.913081e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 9.945585e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 3.036509e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.647610e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 8.363405e-08
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 1.920849e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 9.928844e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 3.038330e-07
#   warnings.warn(
# /usr/lib/python3.9/site-packages/scipy/integrate/_quadrature.py:245: AccuracyWarning: maxiter (50) exceeded. Latest difference = 2.648386e-07
#   warnings.warn(

# %% [markdown]
# ## Test performance with positive regularization

# %%
p = 512
n = 512
n_test = n
c = p/n

mu = np.concatenate([[np.sqrt(2)],np.zeros(p-1)])
norm_mu2 = np.linalg.norm(mu)**2
gamma = 0.1  # regularization penalty

t_max = 1000
alpha = 1e-1

sigma2_init = .1
w_init = np.sqrt(sigma2_init)*np.random.randn(p)/np.sqrt(p)

cs = [1/2,1/2]
lambda_s = c + 1 + norm_mu2 + c/norm_mu2

# Theory
tolerance = 1e-10

f  = lambda x,t : np.exp(-alpha*x*t)
omega = lambda x : np.sqrt(4*c*x - (1-c-x)**2)/(lambda_s-x)/2/pi
nu = lambda x : np.sqrt(4*c*x - (1-c-x)**2)/(2*pi*c*x)

E_test_func = lambda x,t : (1 - f(x+gamma,t))/(gamma+x)*omega(x)
E_test = lambda t : scipy.integrate.quad( lambda x : E_test_func(x,t), (1-np.sqrt(c))**2+tolerance, (1+np.sqrt(c))**2-tolerance,epsabs=tolerance,epsrel=tolerance)[0] + np.max(norm_mu2**2-c,0)/norm_mu2*(1 - f(lambda_s+gamma,t))/(lambda_s+gamma)
V_test_func1 = lambda x,t : (1 - f(x+gamma,t))**2/((x+gamma)**2)*omega(x)
V_test_func2 = lambda x,t : (f(x+gamma,t))**2*nu(x)
V_test = lambda t : (norm_mu2+c)/norm_mu2*( scipy.integrate.quad( lambda x : V_test_func1(x,t), (1-np.sqrt(c))**2+tolerance, (1+np.sqrt(c))**2-tolerance,epsabs=tolerance,epsrel=tolerance)[0] + np.max(norm_mu2**2-c,0)/norm_mu2*(1 - f(lambda_s+gamma,t))**2/((lambda_s+gamma)**2)) + sigma2_init*(scipy.integrate.quad( lambda x : V_test_func2(x,t), (1-np.sqrt(c))**2+tolerance, (1+np.sqrt(c))**2-tolerance,epsabs=tolerance,epsrel=tolerance)[0] + np.max(1-1/c,0)*f(gamma,t)**2 )

E_train = lambda t : (norm_mu2+c)/norm_mu2*E_test(t)
V_train_func1 = lambda x,t : x*(1 - f(x+gamma,t))**2/((gamma+x)**2)*omega(x)
V_train_func2 = lambda x,t : x*(f(x+gamma,t))**2*nu(x)
V_train = lambda t : (norm_mu2+c)/norm_mu2*( scipy.integrate.quad( lambda x : V_train_func1(x,t), (1-np.sqrt(c))**2+tolerance, (1+np.sqrt(c))**2-tolerance,epsabs=tolerance,epsrel=tolerance)[0] + np.max(norm_mu2**2-c,0)/norm_mu2*lambda_s*(1 - f(lambda_s+gamma,t))**2/((lambda_s+gamma)**2)) + sigma2_init*scipy.integrate.quad( lambda x : V_train_func2(x,t), (1-np.sqrt(c))**2+tolerance, (1+np.sqrt(c))**2-tolerance,epsabs=tolerance,epsrel=tolerance)[0] - E_train(t)**2  #+ max(1-1/c,0)*0*f(gamma,t)**2

qfunc = lambda x : 0.5 - 0.5*scipy.special.erf(x/np.sqrt(2))
store_theory = np.zeros((t_max,2))
for t in range(t_max):
    store_theory[t,0] = qfunc(E_train(t)/np.sqrt(np.maximum(V_train(t),1e-10))) # train theory
    store_theory[t,1] = qfunc(E_test(t)/np.sqrt(np.maximum(V_test(t),1e-10))) # test theory

# Empirical
nb_data_loop = 1
store_perf = np.zeros((t_max,nb_data_loop,2))

for data_loop in range(nb_data_loop):

    y = np.concatenate([-np.ones(int(n*cs[0])),np.ones(int(n*cs[1]))])
    X = np.outer(mu,y) + np.random.randn(p,n)

    y_test = np.concatenate([-np.ones(int(n_test*cs[0])),np.ones(int(n_test*cs[1]))])
    X_test = np.outer(mu,y_test) + np.random.randn(p,n_test)

    w = w_init

    for t in range(t_max):
        store_perf[t,data_loop,0] = 1 - np.sum( np.sign(X.T@w)==y )/n # training error rate
        store_perf[t,data_loop,1] = 1 - np.sum( np.sign(X_test.T@w)==y_test )/n_test # test error rate
        w = gd(w, X, y, gamma, alpha, 1)
        
time = np.concatenate([np.arange(10),[10**t for t in np.arange(1,3,.1)] ]).astype(int)
plt.semilogx(time,np.mean(store_perf[time,:,0],1),'bx',label='Empirical training error')
plt.semilogx(time,np.mean(store_perf[time,:,1],1),'bo',label='Empirical test error')
plt.semilogx(time,store_theory[time,0],'r-',label='Asymptotic training error')
plt.semilogx(time,store_theory[time,1],'r--',label='Asymptotic test error')    
_ = plt.legend()
# Out:
# <ipython-input-164-e361c5b01116>:35: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   V_train = lambda t : (norm_mu2+c)/norm_mu2*( scipy.integrate.quad( lambda x : V_train_func1(x,t), (1-np.sqrt(c))**2+tolerance, (1+np.sqrt(c))**2-tolerance,epsabs=tolerance,epsrel=tolerance)[0] + np.max(norm_mu2**2-c,0)/norm_mu2*lambda_s*(1 - f(lambda_s+gamma,t))**2/((lambda_s+gamma)**2)) + sigma2_init*scipy.integrate.quad( lambda x : V_train_func2(x,t), (1-np.sqrt(c))**2+tolerance, (1+np.sqrt(c))**2-tolerance,epsabs=tolerance,epsrel=tolerance)[0] - E_train(t)**2  #+ max(1-1/c,0)*0*f(gamma,t)**2
# <ipython-input-164-e361c5b01116>:30: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   V_test = lambda t : (norm_mu2+c)/norm_mu2*( scipy.integrate.quad( lambda x : V_test_func1(x,t), (1-np.sqrt(c))**2+tolerance, (1+np.sqrt(c))**2-tolerance,epsabs=tolerance,epsrel=tolerance)[0] + np.max(norm_mu2**2-c,0)/norm_mu2*(1 - f(lambda_s+gamma,t))**2/((lambda_s+gamma)**2)) + sigma2_init*(scipy.integrate.quad( lambda x : V_test_func2(x,t), (1-np.sqrt(c))**2+tolerance, (1+np.sqrt(c))**2-tolerance,epsabs=tolerance,epsrel=tolerance)[0] + np.max(1-1/c,0)*f(gamma,t)**2 )

# %% [markdown]
# ## FUNCTIONS

# %%
def gd(w0, X, y, gamma, step, nb_step):
    p,n = np.shape(X)
    w_tmp = w0

    while nb_step > 0:
        g = (X@X.T/n + gamma*np.eye(p))@w_tmp - X@y/n

        # take gradient step
        w_new = w_tmp - step*g
    
        nb_step -= 1
        w_tmp = w_new
        
    return w_new
